# %% [markdown]
# BASIC IF ELSE STATEMENTS

# %%
# 1. Write a python program to check if a given number is positive or negative.
a=int(input("Enter Number : "))

if(a>=0):
    print("Given Number is POSITIVE.")
else:
    print("Give Number is NEGATIVE.")

# %%
#2.Create a program that determines if a person is eligible to vote based on their age.
age= int(input("Enter age(age>0) : "))

if(age>=18):
    print("You can vote.")
else:
    print("You cannt vote.")

# %%
#3. Develop a program to find the maximum of two numbers using if else statements.
first_number =int(input("Enter First Number : "))
second_number=int(input("Enter second number :"))

if(first_number > second_number ):
    print("Largest number ",first_number)
else:
    print("Largest Number ",second_number)

# %%
#4. Write a Python script to classify a given year as a leap year or not. 
year= int(input("Enter year :"))

if(year%4==0 and year%100!=0) or (year%400==0):
    print("Given year is Leap Year.")
else:
    print("Given year is NOT Leap Year.")

# %%
#5.Create a program that checks whether a character is a vowel or a consonant.
character= input("Enter any character :")

if(character=="a" or character=="e"or character=="i" or character=="o" or character=="u"or character=="A" or character=="E"or character=="I" or character=="O" or character=="U"):
    print("Given character is VOWEL.")
else:
    print("Given character is a CONSONANT.")

# %%
#6. Implement a program to determine whether a given number is even or odd
number=int(input("Enter number : "))

if(number%2==0):
    print("Given number is even no.")
else:
    print("Given number is odd no.")

# %%
# 7. Write a Python function to calculate the absolute value of a number without using the 'abs()' function.
given_number= int(input("Enter number "))
if(given_number>=0):
    print(given_number)
else:
    print(-given_number)

# %%
# 8. Develop a program that determines the largest of three given number using if -else statement
first_number= int(input("Enter 1st number: "))
second_number=int(input("Enter 2nd number : "))
third_number=int(input("Enter 3rd number : "))

if(first_number> second_number and first_number> third_number):
    print("Largest Number : ",first_number)
elif(second_number>first_number and second_number>third_number):
    print("Largest Number : ",second_number)
else:
    print("Largest Number : ",third_number)

# %%
#9.Create a Python program that checks if a given string is a palindrome.
string =input("Enter nay string : " )
new_string = string[::-1]

if(string== new_string):
    print(f"{string} is palindrome.")
else:
    print(f"{string} is not palindrome.")

# %%
# 10. Write a Python Program to calculate the grade based on a student's score.
score=int(input("Enter score : "))
if(score>=90):
    print("Grade = +A")
elif(score>=80):
    print("Grade = A")
elif(score>=70):
    print("Grade =+B")
elif(score>=60):
    print("Grade =B")
elif(score>=50):
    print("Grade =+C")
elif(score>=40):
    print("Grade =C")
elif(score>=30):
    print("Grade =D")
else:
    print("You are FAIL")

# %% [markdown]
# NESTED IF ELSE

# %%
#11. Write a program to find the largest among three numbers using nested if-else statements.
first_number= int(input("Enter first  number : "))
second_number=int(input("Enter second number : "))
third_number= int(input("Enter third number : "))

if(first_number>=second_number):
    if(first_number>=third_number):
        print("Largest number : ",first_number)
    else:
        print("Largest number : ", third_number)

else:
    if(second_number>=third_number):
        print("Largest number: ",second_number)
    else:
        print("Largest number : ",third_number)

# %%
# 12. Implement a program to determine if a triangle is equilateral ,isosceles or scalene
first_side = float(input("Enter first side : "))
second_side = float(input("Enter second side : "))
third_side=float(input("Enter third side : "))

if(first_side == second_side):
    if(first_side==third_side):
        print("EQUILATERAL TRIANGLE")
    else:
        print("ISOSCELES TRIANGLE")

else:
    if(third_side==second_side or first_side ==third_side ):
        print("ISOSCELES TRIANGLE")
    else:
        print("SCALENE TRIANGLE")

# %%
#13. Develop a program that checks if a lear is a leap year and also it is a century year.
year=int(input("Enter year : "))

if(year%4==0 and year%100!=0) or (year%400==0) :
    if(year%100==0):
        print("Given year is leap year as well as century year")
    else:
        print("Given year is leap year and not century year")
else:
    if year%100==0:
        print("Giver year is a century year but not leap year.")
    else:
        print("Given year is neither leap year nor leap year.")

# %%
#14. Write a python script to determine if a number s positive ,negative or zero. 
number=int(input("Enter number :"))

if(number>=0):
    if(number==0):
        print("Given number is zero")
    else:
        print("GIven number is positive")
else:
    print("Given number is negative")

# %%
#15. Create a program to check if a person is a teenager (between 13 and 19 years old).
age=int(input("Enter age : "))

if(age>=13):
    if(age<=19):
        print("Person is a TEENAGER.")
    else:
        print("Person is NOT TEENAGER.")
else:
    print("Person is NOT TEENAGER.")

# %%
#16. Develop a program that deetermines the type of angle based on its measure.
angle=float(input("Enter angle (O to 180): "))

if(angle>=90):
    if(angle==90):
        print("RIGHT ANGLE")
    else:
        print("OBTUSE ANGLE")
else:
    print("ACUTE ANGLE")

# %%
# 17. Write a python program to calculate the roots of  a quadratic equation.
# General expression of quadratic equation is ax^2 +bx +c=0
a=int(input("Enter value of a  : "))
b=int(input("Enter value of b  : "))
c=int(input("Enter value of c : "))

discriminant=b*b -4*a*c
root1= (-b+ (discriminant)**0.5)/2*a
root2= (-b- (discriminant)**0.5)/2*a

if(discriminant>=0):
    if(discriminant==0):
        print("Roots are Real and Equal.")
        print("Root1 : ",root1)
        print("Root2 : ",root2)
        
    else:
        print("Roots are Real and Different.")
        print("Root1 : ",root1)
        print("Root2 : ",root2)
else:
    print("Roots are Imaginary.")

# %%
# 18. Implement a program to determine the day of the week based on a user-provided number (1 for Monday, 2 for Tuesday, etc.).
day=int(input("Enter number (1-7) : "))

if(day<=0 or day>7):
    print("Invalid number. ")

else:
    if (day==1):
        print("Monday")
    elif(day==2):
         print("Tuesday")
    elif(day==3):
        print("Wednesday")
    elif(day==4):
       print("Thrusday")
    elif(day==5):
        print("Friday")
    elif(day==6):
        print("Saturday")
    else :
        print("Sunday")

# %%
# 19.Create a program that determines if a year is a leap year and also if it is evenly divisible by 400.
year=int(input("Enter year : "))

if(year%4==0 and year%100!=0) or year%400==0:
    if(year%400==0):
        print("Given year is leap year as well as divisible by 400.")
    else:
        print("Given year is leap year but not divisible by 400")
else:
    print("Given year is not leap year")

# %%
# 20 Develop a program that checks if a given number is prime or not using nested if else statements.
number= int(input("Enter number : "))

if number>1:
    for i in range(2,number):
        if number%i==0:
            print(f"{number} is not a prime number.")
            break
    else:
        print(f"{number} is a prime number. ")
else:
    print(f"{number} is not a prime number. ")

# %% [markdown]
# ELIF STATEMENTS:

# %%
# 21. Write  a python program to assign grades base don different ranges of scores using elif statements.
score=int(input("Enter score : "))
if(score>=90):
    print("Grade = +A")
elif(score>=80):
    print("Grade = A")
elif(score>=70):
    print("Grade =+B")
elif(score>=60):
    print("Grade =B")
elif(score>=50):
    print("Grade =+C")
elif(score>=40):
    print("Grade =C")
elif(score>=30):
    print("Grade =D")
else:
    print("You are FAIL")

# %%
# 22. Implement a program to determine the type of triangle based on its angle.
print("Enter angle in such a way the sum of three angle should be 180.")
angle1=float(input("Enter 1st angle : "))
angle2=float(input("Enter 2nd angle : "))
angle3=float(input("Enter 3rd angle : "))

if(angle1==angle2==angle3):
    print("EQUILATERAL TRIANGLE")
elif(angle3==angle1 or angle1==angle2 or angle2==angle3):
    print("ISOSCELES TRIANGLE")
else:
    print("SCALENE TRIANGLE")

# %%
# 23. Develop a program  to categorise a given person BMI  into underweight ,normal,overweight or obese using elif statements.
weight= float(input("Enter weight(kg) : "))
height= float(input("Enter height(m) : "))

BMI= weight/(height**2)

if BMI<= 18.5:
    print("You are Underweight.")
elif 18.5<BMI<=24.9:
    print("You are normal.")
elif 25<= BMI<=29.9:
    print("You are overweight.")
else:
    print("You are obese.")

# %%
# 24. Create a program that determines whether a given number is positive negative or zero.
number=int(input("Enter number :"))

if(number==0):
    print("Given number is zero")
elif(number>0):
    print("GIven number is positive")
else:
    print("Given number is negative")

# %%
# 25. Write a Python script to determine the type of a character (uppercase, lowercase, or special) using elif statements.
char = input("Enter Character : ")
if "a"<= char <="z":
    print(char,"is Lowecase.")
elif "A"<= char<="Z":
    print(char,"is Uppercase.")
else:
    print(char," is Special character")

# %%
#26. Implement a program to calculate the discounted price based on different purchase amounts using elif statements
purchase_amount = float(input("Enter purchase amount of product : "))

if purchase_amount<=1000:
    discount_price=0
    bill_amount= purchase_amount 
    print("Bill amount :",bill_amount)

elif  1000<purchase_amount <=5000:
    discount_price=0.1
    bill_amount=purchase_amount- purchase_amount*0.1
    print("Bill amount : ",bill_amount)

elif 5000<purchase_amount<=10000:
    discount_price = 0.2
    bill_amount=purchase_amount - purchase_amount*0.2
    print("Bill amount : ",bill_amount)

else:
    discount_price = 0.3
    bill_amount = purchase_amount - purchase_amount*0.3
    print("Bill amount : ",bill_amount)

# %%
# 27. Develop a program to calculate the electricity bill based on different consumption slabs using elif  statements.
units= float(input("Enter units : "))

if units<=50:
    price= units*2
    print("Electricity bill : ",price)
elif 51<= units<=150:
    price=50*2 + (units-50)*2.50
    print("Electricity bill : ",price)
elif 151<= units<=250:
    price=50*2 + 100*2.50 +(units-150)*5.25
    print("Electricity bill : ",price)
elif 251<= units<=600:
    price= 50*2 + 100*2.50 + 100*5.25 +(units-250)*7.10
    print("Electricity bill : ",price)
else:
    price= 50*2 + 100*2.50 +100*5.25 + 350*7.10 + (units-600)*8.10
    print("Electricity bill : ",price)

# %%
# 28. Create a program to determine the type of quadrilateral based on its angles and sides using elif statements.
print("Make sure the sum of angle of quadrilateral is 360  ")
side1 =float(input("Enter 1st side of quadrilateral : "))
side2 =float(input("Enter 2nd side of quadrilateral : "))
side3 =float(input("Enter 3rd side of quadrilateral : "))
side4 =float(input("Enter 4th side of quadrilateral : "))
angle1=float(input("Enter 1st angle for quadrilateral : "))
angle2=float(input("Enter 2nd angle for quadrilateral : "))
angle3=float(input("Enter 3rd angle for quadrilateral : "))
angle4=float(input("Enter 4th angle for quadrilateral : "))

if(side1==side2==side3==side4 and angle1==angle2==angle3==angle4==90):
    print("So the quadrilateral is  square.")

elif (side1==side3 and side2==side4)  and (angle1==angle2==angle3==angle4==90):
    print("So the quadrilateral is rectangle")

elif (side1==side2==side3==side4)  and (angle1==angle3 and angle2==angle4):
    print("So the quadrilateral is rhombus")

elif (side1==side3 and side2==side4)  and (angle1==angle3 and angle2==angle4):
    print("So the quadrilateral is parallelogram.")
    
else:
    print("Enter right side and angle.")

# %%
# 29. Write a Python script to determine the season based on a user-provided month using elif statements.
print("""1=Janury
2=Febuary
3=March
4=Arpil
5=May
6= June
7=July
8=August
9=September
10 = October
11= November
12=December """)

month_number= int(input("Enter no acc togiven data : "))

if 1<=month_number<=3 or 11<=month_number<=12:
    print("Winter Season")
elif 4<=month_number<=7:
    print("Summer Season")
else:
    print("Rainy Season")

# %%
#  30. Implement a program to determine the type of a year (leap or common) and month (30 or 31 days) using elif statements
year= int(input("Enter year : "))
month=input("Enter any month : ")
lower_month =month.lower()
capatalise = lower_month.capitalize()
month_30 = ["april","june","september","november"]
month_31 = ["january","march","may","july","august","october","december"]

if (year%4 ==0 and year%100!=0) or year%400==0:
    print("Leap year.")
else:
    print("Not leap year.")


if lower_month in month_30:
    print(f"{capatalise} is 30 days")
    

elif lower_month in month_31:
    print(f"{capatalise} is 31 days.")
    

elif lower_month=="febuary":
    if( year%4==0 and year%100!=0) or year%400==0:
        print(f"{capatalise} is 29 days.")
    else: 
        print(f"{capatalise} is 28 days.")#

# %% [markdown]
# BASIC LEVEL

# %%
# 1. Write a Python program that checks if a given number is positive, negative, or zero.
number=int(input("Enter number :"))

if(number==0):
    print("Given number is zero")
elif(number>0):
    print("GIven number is positive")
else:
    print("Given number is negative")

# %%
# 2. Create a program to determine if a person is eligible to vote based on their age
age= int(input("Enter age(age>0) : "))

if(age>=18):
    print("You can vote.")
else:
    print("You cannt vote.")

# %%
# 3. Write a program to find the maximum of two given numbers using conditional statements.
first_number =int(input("Enter First Number : "))
second_number=int(input("Enter second number :"))

if(first_number > second_number ):
    print("Largest number ",first_number)
else:
    print("Largest Number ",second_number)

# %%
# 4. Develop a program that calculates the grade of a student based on their exam score.
score=int(input("Enter score : "))
if(score>=90):
    print("Grade = +A")
elif(score>=80):
    print("Grade = A")
elif(score>=70):
    print("Grade =+B")
elif(score>=60):
    print("Grade =B")
elif(score>=50):
    print("Grade =+C")
elif(score>=40):
    print("Grade =C")
elif(score>=30):
    print("Grade =D")
else:
    print("You are FAIL")

# %%
# 5. Create a program that checks if a year is a leap year or not.
year= int(input("Enter year :"))

if(year%4==0 and year%100!=0) or year%400==0:
    print("Given year is Leap Year.")
else:
    print("Given year is NOT Leap Year.")

# %%
# 6. Write a program to classify a triangle based on its sides' lengths.
first_side = float(input("Enter first side : "))
second_side = float(input("Enter second side : "))
third_side=float(input("Enter third side : "))

if(first_side == second_side):
    if(first_side==third_side):
        print("EQUILATERAL TRIANGLE")
    else:
        print("ISOSCELES TRIANGLE")

else:
    if(third_side==second_side or first_side ==third_side ):
        print("ISOSCELES TRIANGLE")
    else:
        print("SCALENE TRIANGLE")

# %%
# 7. Build a program that determines the largest of three given numbers.
first_number= int(input("Enter 1st number: "))
second_number=int(input("Enter 2nd number : "))
third_number=int(input("Enter 3rd number : "))

if(first_number> second_number and first_number> third_number):
    print("Largest Number : ",first_number)
elif(second_number>first_number and second_number>third_number):
    print("Largest Number : ",second_number)
else:
    print("Largest Number : ",third_number)

# %%
# 8. Develop a program that checks whether a character is a vowel or a consonant.
character= input("Enter any character :")

if(character=="a" or character=="e"or character=="i" or character=="o" or character=="u"or character=="A" or character=="E"or character=="I" or character=="O" or character=="U"):
    print("Given character is VOWEL.")
else:
    print("Given character is a CONSONANT.")

# %%
# 9. Create a program to calculate the total cost of a shopping cart based on discounts.
purchase_amount = float(input("Enter purchase amount of product : "))

if purchase_amount<=1000:
    discount_price=0
    bill_amount= purchase_amount 
    print("Bill amount :",bill_amount)

elif  1000<purchase_amount <=5000:
    discount_price=0.1
    bill_amount=purchase_amount- purchase_amount*0.1
    print("Bill amount : ",bill_amount)

elif 5000<purchase_amount<=10000:
    discount_price = 0.2
    bill_amount=purchase_amount - purchase_amount*0.2
    print("Bill amount : ",bill_amount)

else:
    discount_price = 0.3
    bill_amount = purchase_amount - purchase_amount*0.3
    print("Bill amount : ",bill_amount)

# %%
# 10. Write a program that checks if a given number is even or odd.
number=int(input("Enter number : "))

if(number%2==0):
    print("Given number is even no.")
else:
    print("Given number is odd no.")

# %% [markdown]
# INTERMEDIATE LEVEL

# %%
# 11. Write a program that calculates the roots of a quadratic equation .
# General expression of quadratic equation is ax^2 +bx +c=0
a=int(input("Enter value of a  : "))
b=int(input("Enter value of b  : "))
c=int(input("Enter value of c : "))

discriminant=b*b -4*a*c
root1= (-b+ (discriminant)**0.5)/2*a
root2= (-b- (discriminant)**0.5)/2*a

if(discriminant>=0):
    if(discriminant==0):
        print("Roots are Real and Equal.")
        print("Root1 : ",root1)
        print("Root2 : ",root2)
        
    else:
        print("Roots are Real and Different.")
        print("Root1 : ",root1)
        print("Root2 : ",root2)
else:
    print("Roots are Imaginary.")

# %%
# 12. Create a program that determines the day of the week based on the day number (1-7).
day=int(input("Enter number (1-7) : "))

if(day<=0 or day>7):
    print("Invalid number. ")

else:
    if (day==1):
        print("Monday")
    elif(day==2):
         print("Tuesday")
    elif(day==3):
        print("Wednesday")
    elif(day==4):
       print("Thrusday")
    elif(day==5):
        print("Friday")
    elif(day==6):
        print("Saturday")
    else :
        print("Sunday")

# %%
# 13. Develop a program that calculates the factorial of a given number using recursion.
def factorial(n):
    if n==1 or n==0:
        return 1
    else:
        return n*factorial(n-1)
    
n= int(input("Enter positive number : "))
print(f"The factorial of {n} :",factorial(n))

# %%
# 14. Write a program to find the largest among three numbers without using the `max()` function.
first_number= int(input("Enter 1st number: "))
second_number=int(input("Enter 2nd number : "))
third_number=int(input("Enter 3rd number : "))

if(first_number> second_number and first_number> third_number):
    print("Largest Number : ",first_number)
elif(second_number>first_number and second_number>third_number):
    print("Largest Number : ",second_number)
else:
    print("Largest Number : ",third_number)

# %%
# 15. Create a program that simulates a basic ATM transaction menu.
print("1= Check Balance \n2= Deposit Money \n3=Withdraw Money ")
balance=10000
menu = int(input("Enter your choice (1-3): "))

if(menu==1):
    print("Your balance is ",balance)

elif menu==2:
    add_money =int(input("Enter money : "))
    print("Your money  is ",balance+add_money)
elif menu==3:
    withdraw_money= int(input("Enter withdraw money : "))
    print("Your balance is ",balance-withdraw_money)
else:
    print("Pleas enter only 1 to 3.")

# %%
# 16. Build a program that checks if a given string is a palindrome or not.
string =input("Enter nay string : " )
new_string = string[::-1]

if(string== new_string):
    print(f"{string} is palindrome.")
else:
    print(f"{string} is not palindrome.")

# %%
# 17. Write a program that calculates the average of a list of numbers, excluding the smallest and largest values.
length= int(input("Enter length of list: "))
l=[]
print("Enter element of list")
for i in  range(length):
    m=int(input())
    l.append(m)

l.sort()
l.pop()
l.pop(0)
sum=0
new_len = len(l)
for i in l:
    sum=sum+i

print("Average of given list : ",sum/new_len)

# %%
# 18. Develop a program that converts a given temperature from Celsius to Fahrenheit.
Celsius_temp=float(input("Enter temperature in Celsius = "))
Fahrenheit_Temp=1.8*Celsius_temp+32
print("Temperature in Fahrenheit = ",Fahrenheit_Temp)

# %%
# 19. Create a program that simulates a basic calculator for addition, subtraction, multiplication, and division.
a=int(input("Enter 1st number : "))
b=int(input("Enter 2ndnumber : "))
operator= input("Enter opeator(+,-,*,/) :")

if(operator=="+"):
    print("Sum is ",a+b)
elif(operator=="-"):
    print("Difference is",a-b)
elif(operator=="*"):
    print("Multiply is ",a*b)
elif(operator=="/"):
    print("Divide is ",a/b)
else:
    print("Invalid operator")

# %%
# 20. Write a program that determines the roots of a cubic equation using the Cardano formula.
print("The cubic equations : ax^3 + bx^2 +cx +d = 0")
a=int(input("Enter the value of a : "))
b=int(input("Enter the value of b : "))
c=int(input("Enter rhe value of c : "))
d=int(input("Enter the value of d : "))

p = (3*a*c - b**2) / (3*a**2)
q = (2*b**3 - 9*a*b*c + 27*a**2*d) / (27*a**3)

D = q**2 / 4 + p**3 / 27

if D>0 :
    sqrt_D= D**0.5
    if (-q/2 + sqrt_D) >= 0:
        u=(-q/2 + sqrt_D)**(1/3)
    else:
        u=-((-q/2 + sqrt_D)**(1/3))
        
    if (-q/2 - sqrt_D) >= 0 :
        v=(-q/2 - sqrt_D)**(1/3)
    else:
        v=-((-q/2 - sqrt_D)**(1/3))
    
    real_root = u + v - b / (3*a)
    imaginary_part= ((3**0.5)/2)*(u-v)

    root1=real_root
    root2= -0.5*(u+v) -b/(3*a) +imaginary_part*1j
    root3= -0.5*(u+v) -b/(3*a) -imaginary_part*1j

    print("Roots of the cubic equation : ")
    print("Root 1 : ",root1)
    print("Root 2 : ",root2)
    print("Root 3 : ",root3)

elif D==0:
    if (-q/2) >= 0 :
        u = (-q/2)**(1/3)
    else:
        u = -((-q/2)**(1/3)) 

    root1 =u + (-u) - b / (3*a)

    print("Roots of the cubic equation:")
    print(root1)

else:
    sqrt_D= (-D)**0.5
    u = ((-q/2) + sqrt_D)**(1/3)
    v = ((-q/2) - sqrt_D)**(1/3)
    
    root1 = u + v - b / (3*a)
    
    print("Roots of the cubic equation:")
    print(root1)

# %% [markdown]
# ADVANCED LEVEL

# %%
# 21. Create a program that calculates the income tax based on the user's income and tax brackets.
income= float(input("Enter your annual income : "))

if 0<=income<=300000:
    tax= 0
    print(tax)

elif 300000 <income<=700000:
    tax=(income-300000)*0.05
    print(tax)
elif 700000< income<=1000000:
    tax=(income-700000)*0.1 + 400000*0.05
    print(tax)
else:
    tax=(income-1000000)*0.15 +300000*0.1+400000*0.05
    print(tax)

# %%
# 22. Write a program that simulates a rock-paper-scissors game against the computer.
import random
actual=input("Enter your choice :")
game = ["rock","paper","scissors"]

guess= random.choice(game)
print("Computer guess",guess)

if actual== "rock" and guess=="rock":
    print("Draw")
elif actual=="rock" and guess=="paper":
    print("You Lost")
elif actual=="rock" and guess=="scissors":
    print("You Won")
elif actual=="paper"and guess=="rock":
    print("You Won")
elif actual=="paper" and guess=="paper":
    print("Draw")
elif actual=="paper" and guess=="scissors":
    print("You Lost")
elif actual=="scissors" and guess=="rock":
    print("You Lost")
elif actual=="scissors" and guess=="paper":
    print("You Won")
elif actual=="scissors" and guess=="scissors":
    print("Draw")

# %%
# 23. Develop a program that generates a random password based on user preferences (length, complexity).
import random 
import string

letters=[]
number=[]
special_character=[]
letters.extend(string.ascii_lowercase)
letters.extend(string.ascii_uppercase)
number.extend(string.digits)
special_character.extend(string.punctuation)

print("Welcome to password generator ")
number_of_letters=int(input("How many letters you want in password : "))
totalnumbers=int(input("How many numbers you want in password : "))
character=int(input("How many special character in password :  "))

list1=[]
for char in range(number_of_letters):
    a=random.choice(letters)
    list1+=a

for i in range(totalnumbers):
    a=random.choice(number)
    list1+=a

for i in range(character):
    a=random.choice(special_character)
    list1+=a

print(list1)
random.shuffle(list1)

password="".join(list1)
print("Your password is : \n",password)

# %%
# 24. Create a program that implements a simple text-based adventure game with branching scenarios.
print("Welcome to the Adventure Game!")
print("You find yourself standing at the entrance of a dark forest.")
print("You can either enter the forest or walk away.")

print("Do you enter the forest or walk away? (Enter/Walk) ")
CHOICE1 = input()
choice1=CHOICE1.lower()
if choice1 == 'enter':
    print("You step into the forest. The trees are tall and the path is winding.")
    print("Suddenly, you come across a fork in the road.")
    print("Do you take the left path or the right path? (Left/Right)")
    CHOICE2 = input("Enter :")
    choice2=CHOICE2.lower()
    if choice2 == 'left':
        print("You take the left path and encounter a mysterious old man.")
        print("The old man offers you a choice: a magical potion or a treasure map.")
        print("Do you accept the potion or take the map? (Potion/Map)")
        CHOICE3 = input()
        choice3=CHOICE3.lower()
        if choice3 == 'potion':
            print("You drink the potion and feel a surge of power!")
            print("Suddenly, you find yourself in front of a hidden treasure chest.")
            print("Congratulations! You've found the treasure and won the game!")
        elif choice3 == 'map':
            print("You take the map and follow its directions.")
            print("The map leads you to a beautiful waterfall where you find a hidden cave.")
            print("Inside the cave, you find ancient artifacts. You've discovered a great secret!")
        else:
            print("The old man disappears and you are left in confusion. You find your way back home.")
    
    elif choice2 == 'right':
        print("You take the right path and find a small village.")
        print("The villagers are friendly and invite you to a feast.")
        print("After the feast, they offer you a choice: stay and live with them or continue your journey.")
        print("Do you stay or continue? (Stay/Continue)")
        CHOICE4 = input()
        choice4=CHOICE4.lower()
        if choice4 == 'stay':
            print("You choose to stay and live among the villagers.")
            print("You lead a happy life and become an integral part of the community. Congratulations!")
        elif choice4 == 'continue':
            print("You continue your journey and eventually return home, enriched by your adventures.")
        else:
            print("The villagers are puzzled by your indecision and you find yourself lost in the forest.")
    
    else:
        print("You wander off and get lost in the forest. The adventure ends here.")

elif choice1 == 'walk':
    print("You decide to walk away and head back home.")
    print("You may have missed out on an adventure, but you're safe and sound.")

else:
    print("You stand still in confusion and the adventure ends before it begins.")

# %%
# 25. Build a program that solves a linear equation  for x, considering different cases.
print("According to given condition type(1 -2 )")

print("1: ax+b=0\t2:ax-b=0")

a=int(input("Enter a : "))
b=int(input("Enter b : "))
condition=int(input("Enter condition"))

if condition==1:
    print("x= ",-b/a)
else:
    print("x = ",b/a)

# %%
# 26. Write a program that simulates a basic quiz game with multiple-choice questions and scoring.
question_bank=[
{"test" : "Python is generally used in ","answer":"D"},
{"test" : "What is the output of 32//3 ","answer":"C"},
{"test" : "What is the value of x is if x=10 \n x=x+5","answer":"A"},
{"test" : "What of the following is a valid variable name in pyhton","answer":"B"},
{"test" : "What is the correct way to concatenate two strings.","answer":"A"}
]

option=[["A. Data Science","B. Machine Learning","C. Artificial Intelligence","D. All of the above"],
["A. 5", "B. 8","C. 10","D. 15"],
["A. 15","B. 5","C. 10","D. 7"],
["A. 123var","B. var123","C. var-123","D. $var123"],
["A. s1+s2","B. s1:s2","C. s1-s2","D. s1.s2"]
]

score=0
def check_answer(guess_ans,correct_ans):
    if guess_ans==correct_ans:
        return True
    else:
        return False
    
for i in range(len(question_bank)):
    print("**********************************")
    print(question_bank[i]["test"])
    for j in option[i]:
        print(j)
    guess_ans=input("Ans(A/B/C/D) :").upper()
    a=check_answer(guess_ans,question_bank[i]["answer"])
    if a==True:
        score+=1
    else:
        print("correct answer is :",question_bank[i]["answer"])
    print("Current score is : ",score)

print("Total score is : ",score)
print("Percentage : ",score/len(question_bank)*100)

# %%
# 27. Develop a program that determines whether a given year is a prime number or not.
year=int(input("Enter year : "))

for i in range(2,year):
    if year%i==0:
        print("Year is not prime.")
        break

else:
    print("Year is prime")

# %%
# 28. Create a program that sorts three numbers in ascending order using conditional statements.
first_number = int(input("Enter first number : "))
second_number=int(input("Enter second_number : "))
third_number = int(input("Enter third number : "))

print("Ascending order is :")

if first_number> second_number and first_number>third_number:
    if second_number>third_number:
        print(third_number,"\t",second_number,"\t",first_number ) 
    else:
        print(second_number,"\t",third_number,"\t",first_number)

elif second_number>first_number and second_number>third_number:
    if first_number>third_number:
        print(third_number,"\t",first_number,"\t",second_number)
    else:
        print(first_number,"\t",third_number,"\t",second_number)

else:
    if first_number>second_number:
        print(second_number,"\t",first_number,"\t",third_number)
    else:
        print(first_number,"\t",second_number,"\t",third_number)

# %%
# 29. Build a program that determines the roots of a quartic equation using numerical methods.
def f(x):
    return eval(user_function)

def bisection(a,b,n):
    i=1
    while i<n:
        x=(a+b)/2
        if f(x)<0:
            a=x
        else:
            b=x
        print("Iteration number = ",i+1,"\tx = ",x,"\t \tf(x) = ",f(x))

        i+=1
    return x

user_function=input("Enter function :\n")
n=int(input("Enter number of iteration : "))
a=0
b=0
for i in range(-5,5):
    f1=f(i)
    f2=f(i+1)
    if f1*f2<0:
        a=i
        b=i+1
        break
print(a,"\n",b)

print("Required root is : ",bisection(a,b,n))

# %%
# 30. Write a program that calculates the BMI (Body Mass Index) and provides health recommendations based on the user's input.
weight= float(input("Enter weight(kg) : "))
height= float(input("Enter height(m) : "))

BMI= weight/(height**2)

if BMI<= 18.5:
    print("You are Underweight.\nYou need to bulking by taking proper diet.")
elif 18.5<BMI<=24.9:
    print("You are normal.\nYou continue your diet.")
elif 25<= BMI<=29.9:
    print("You are overweight.\nYou start to do gym and make diet according to them")
else:
    print("You are obese.\nYou start to do gym and avoid fast food and make diet according to them")

# %% [markdown]
# Challenge Level:

# %%
# 31. Create a program that validates a password based on complexity rules (length, characters, etc.).
print("Password length should be between 8 to 32.")
print("Password Should start with a to z or A to Z.")
print("Password should contain special character or numbers.")

l=["@","#","$","&","!","?"]

password=input("Enter password : ")
contain= False
if 8<=len(password)<=32  and ("a"<=password[0]<="z" or "A"<=password[0]<="Z"):
    for i in password:
        if "0"<=i<="9":
            for i in password:
                if i in l: 
                    contain= True
                    break

if contain==True:
    print("Password is validates.")
else:
    print("Password is not validates. Pls enter according to description")

# %%
# 32. Develop a program that performs matrix addition and subtraction based on user input.
row=int(input("Enter number of rows : "))
column=int(input("Enter number of column : "))
sign= input("Enter operation : ")

A=[]
for i in range(row):
    rows=[]
    for j in range(column):
        
        element=int(input(f"Enter elements of mtrices of A{i+1}{j+1} : "))
        rows.append(element)
    A.append(rows)

print(A)


B=[]
for i in range(row):
    rows=[]
    for j in range(column):
        
        element=int(input(f"Enter elements of mtrices of B{i+1}{j+1} : "))
        rows.append(element)
    B.append(rows)

print(B)

if sign=="+":
    sum=[]
    for i in range(len(A)):
        output=[]
        for j in range(len(A[0])):
            result=A[i][j]+B[i][j]
            output.append(result)
        sum.append(output)

    print("Sum of given matrices :")
    print(sum)

elif sign=="-":
    subt=[]
    for i in range(len(A)):
        output=[]
        for j in range(len(A[0])):
            result=A[i][j]-B[i][j]
            output.append(result)
        subt.append(output)
    print("Subtraction of given matrices is : ")
    print(subt)

# %%
# 33. Write a program that calculates the greatest common divisor (GCD) of two numbers using the Euclidean  algorithm.
print("Enter two number")
a=int(input("Enter first number : "))
b=int(input("Enter second number : "))

while b!=0:
    remainder=a%b
    a=b
    b=remainder

gcd=a
print("GCD of given two numbers : ",gcd)

# %%
# 34. Build a program that performs matrix multiplication using nested loops and conditional statements.
row1=int(input("Enter rows of  matrix 1 : "))
column1=int(input("Enter coulmn of  matrix 1 : "))
row2=int(input("Enter rows of matrix 2 : "))
column2=int(input("Enter column of matrix 2 : "))

if  row1 !=column2:
    print("Mupltiplication is not possible.")
else:
    print("Enter the element of matrix 1 : ")
    A=[]
    for i in range(row1):
        row=[]
        for j in range(column1):
            inp=int(input(f"Enter [{i+1}][{j+1}] : "))
            row.append(inp)
        A.append(row)

    print("Enter the element of matrix 2 : ")
    B=[]
    for i in range(row2):
        row=[]
        for j in range(column2):
            inp=int(input(f"Enter [{i+1}][{j+1}] : "))
            row.append(inp)
        B.append(row)

    product=[]
    for i in range(row1):
        row=[]
        for j in range(column2):
            row.append(0)
        product.append(row)


    for i in range(row1):
        for j in range(column2):
            for k in range(column1):
                product[i][j]+=  A[i][k]*B[k][j]
            
    print("Matrix A is : ")
    for i in A:
        print(i)
    print("Matrix B is :")
    for i in B:
        print(i)
    print("Resultant of both matrix is : ")
    for i in product:
        print(i)

# %%
#35 Create a program that simulates a basic text-based tic-tac-toe game against the computer
import random

print("WELCOME TO TIC TAC TOE")
print("----------------------")

possiblenumbers = [1, 2, 3, 4, 5, 6, 7, 8, 9]
gameboard = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
rows = 3
columns = 3

def printGameBoard():
    for x in range(rows):
        print("\n+---+---+---+")
        print("|", end="")
        for y in range(columns):
            print("", gameboard[x][y], end=" |")
    print("\n+---+---+---+")

def modifyArray(num, turn):
    num -= 1
    if num == 0:
        gameboard[0][0] = turn
    elif num == 1:
        gameboard[0][1] = turn
    elif num == 2:
        gameboard[0][2] = turn
    elif num == 3:
        gameboard[1][0] = turn
    elif num == 4:
        gameboard[1][1] = turn
    elif num == 5:
        gameboard[1][2] = turn
    elif num == 6:
        gameboard[2][0] = turn
    elif num == 7:
        gameboard[2][1] = turn
    elif num == 8:
        gameboard[2][2] = turn

def checkForWinner(gameboard):
    # Check rows for a winner
    for row in gameboard:
        if row[0] == row[1] == row[2]:
            print(f"{row[0]} WON!")
            return row[0]

    # Check columns for a winner
    for col in range(columns):
        if gameboard[0][col] == gameboard[1][col] == gameboard[2][col]:
            print(f"{gameboard[0][col]} WON!")
            return gameboard[0][col]

    # Check diagonals for a winner
    if gameboard[0][0] == gameboard[1][1] == gameboard[2][2]:
        print(f"{gameboard[0][0]} WON!")
        return gameboard[0][0]
    if gameboard[0][2] == gameboard[1][1] == gameboard[2][0]:
        print(f"{gameboard[0][2]} WON!")
        return gameboard[0][2]

    # Check for a tie
    if len(possiblenumbers) == 0:
        print("IT'S A TIE!")
        return "Tie"

    return None

leaveLoop = False
turnCounter = 0

while not leaveLoop:
    # Player's turn
    if turnCounter % 2 == 0:
        printGameBoard()
        numberPicked = int(input("Choose a number [1-9]: "))
        if numberPicked in possiblenumbers:
            modifyArray(numberPicked, 'X')
            possiblenumbers.remove(numberPicked)
            turnCounter += 1
        else:
            print("Invalid move. Try again.")

    # Computer's turn
    else:
        cpuChoice = random.choice(possiblenumbers)
        print(f"CPU choice: {cpuChoice}")
        modifyArray(cpuChoice, 'O')
        possiblenumbers.remove(cpuChoice)
        turnCounter += 1

    # Check for a winner
    winner = checkForWinner(gameboard)
    if winner:
        printGameBoard()
        leaveLoop = True

# %%
# 36. Write a program that generates Fibonacci numbers up to a specified term using iterative methods.
def generate_fibo(n):
    if n<=0:
        return []
    elif n==1:
        return [0]
    elif n==2:
        return [0,1]
    
    fibonacci_sequence=[0,1]
    for i in  range(2,n):
        fibonacci_sequence.append(fibonacci_sequence[-1]+fibonacci_sequence[-2])
    return fibonacci_sequence

numbers=int(input("Enter number : "))
print(generate_fibo(numbers))

# %%
# 37. Develop a program that calculates the nth term of the Fibonacci sequence using memoization.
def fibo(n,memo={}):
    if n<=0:
        return 0
    elif n==1:
        return 1
    
    if n in memo :
        return memo[n]
    
    memo[n]=fibo(n-1,memo)+fibo(n-2,memo)
    return memo[n]

numbers=int(input("ENTERS NUMBERS :"))
print(fibo(numbers))

# %%
# 38. Create a program that generates a calendar for a given month and year using conditional statements.

# %%
# 39. Build a program that simulates a basic text-based blackjack game against the computer.

# %%
#40 Write a program that generates the prime factors of a given number using trial division.
def prime_factors(n):
    factors=[]

    while n%2==0:
        factors.append(n)
        n//=2

    i=3
    while i*i<=n:
        while n%i==0:
            factors.append(i)
            n//=i
        i+=2
    
    if n>2:
        factors.append(n)
    return factors

numbers=int(input("ENTER NUMBERS :"))
print(prime_factors(numbers))
